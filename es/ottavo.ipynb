# %%
# %pip install pandas numpy scikit-learn plotly
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import plotly.graph_objects as go
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import train_test_split
# Out:
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ------------ --------------------------- 2.6/8.2 MB 16.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.2 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 14.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ----------- ---------------------------- 2.9/9.9 MB 15.2 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/9.9 MB 15.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 16.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 13.4 MB/s  0:00:00
# ...
#
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
# ...

# %%
import subprocess

df = pd.read_csv('data.csv')
df = df.dropna()

df['mese_numerico'] = np.arange(len(df))

X = df['mese_numerico'].values.reshape(-1, 1)
Y = df['passengers'].values

grado = 2
modello_polinomiale = make_pipeline(PolynomialFeatures(grado), LinearRegression())
modello_polinomiale.fit(X, Y)

Y_pred = modello_polinomiale.predict(X)

rmse = root_mean_squared_error(Y, Y_pred)
print(f"RMSE: {rmse:.2f}")

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df['date'], 
    y=Y, 
    mode='lines+markers', 
    name='Dati Reali',
    line=dict(color='blue')
))

fig.add_trace(go.Scatter(
    x=df['date'], 
    y=Y_pred, 
    mode='lines', 
    name='Curva Stimata',
    line=dict(color='red', dash='dash', width=3)
))

fig.update_layout(
    title='Regressione Polinomiale sul Traffico Aereo',
    xaxis_title='Data',
    yaxis_title='Passeggeri',
    template='plotly_white'
)

subprocess.check_call(['pip', 'install', '--upgrade', 'nbformat'])
fig.show()
# Out:
# RMSE: 45.23
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 43
#      39     yaxis_title='Passeggeri',
#      40     template='plotly_white'
#      41 )
#      42
# ---> 43 fig.show()
#
# File c:\Users\Rugge\miniconda3\envs\lab_pyhton\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Rugge\miniconda3\envs\lab_pyhton\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
# ...
